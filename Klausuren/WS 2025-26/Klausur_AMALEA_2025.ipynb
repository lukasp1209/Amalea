# %% [markdown]
# # AMALEA 2025 – Klausur (MC & Offene Fragen)
#
# Diese Klausur umfasst 20 Multiple-Choice-Fragen (mit jeweils einer richtigen Antwort, als Task-Liste formatiert) und 10 offene Fragen. Die Fragen decken alle zentralen Themenbereiche des Kurses ab.

# %% [markdown]
# ## Multiple-Choice-Fragen

# %% [markdown]
# **1. Welcher Schritt im QUA³CK-Prozess ist entscheidend, um Datenlecks (Data Leakage) im Machine Learning zu vermeiden?** (2 Punkte)
# - [ ] App
# - [ ] Acquire & Clean
# - [ ] Conclude
# - [ ] Knowledge Transfer

# %% [markdown]
# **2. Welche Aussage beschreibt am besten den Unterschied zwischen Overfitting und Underfitting?** (2 Punkte)
# - [ ] Overfitting: Modell ist zu einfach; Underfitting: Modell ist zu komplex
# - [ ] Overfitting: Modell passt sich zu stark an Trainingsdaten an; Underfitting: Modell kann Muster nicht erfassen
# - [ ] Overfitting: Modell ist zu langsam; Underfitting: Modell ist zu schnell
# - [ ] Overfitting: Modell nutzt zu wenig Features; Underfitting: Modell nutzt zu viele Features

# %% [markdown]
# **3. Welche Technik ist KEIN Bestandteil der explorativen Datenanalyse (EDA)?** (2 Punkte)
# - [ ] Korrelationsanalyse
# - [ ] Boxplot-Visualisierung
# - [ ] Hyperparameter-Tuning
# - [ ] Identifikation von Ausreißern

# %% [markdown]
# **4. Was ist ein typischer Nachteil von Decision Trees ohne weitere Maßnahmen?** (2 Punkte)
# - [ ] Sie sind nicht interpretierbar
# - [ ] Sie neigen zu Overfitting
# - [ ] Sie können keine numerischen Daten verarbeiten
# - [ ] Sie benötigen GPU-Beschleunigung

# %% [markdown]
# **5. Welche Maßnahme erhöht die Reproduzierbarkeit von Data-Science-Projekten am effektivsten?** (2 Punkte)
# - [ ] Nutzung von Jupyter Notebooks
# - [ ] Verwendung von Docker-Containern
# - [ ] Einsatz von Random Forests
# - [ ] Nutzung von Excel für die Datenanalyse

# %% [markdown]
# **6. Welche Aussage zu Feature Engineering ist korrekt?** (2 Punkte)
# - [ ] Feature Engineering ist nur bei Bilddaten relevant
# - [ ] Feature Engineering kann die Modellgüte signifikant verbessern
# - [ ] Feature Engineering ist ausschließlich Aufgabe des Deployments
# - [ ] Feature Engineering ist bei linearen Modellen nicht notwendig

# %% [markdown]
# **7. Welche Methode ist am besten geeignet, um die Robustheit eines Modells gegen Ausreißer zu testen?** (2 Punkte)
# - [ ] Cross-Validation
# - [ ] ROC-AUC-Analyse
# - [ ] Training auf synthetischen Daten
# - [ ] Visualisierung mit Heatmaps

# %% [markdown]
# **8. Was ist ein typisches Symptom für Data Leakage?** (2 Punkte)
# - [ ] Sehr hohe Trainings- und Testgenauigkeit, aber schlechte Generalisierung auf neue Daten
# - [ ] Geringe Trainingsgenauigkeit, aber hohe Testgenauigkeit
# - [ ] Modell kann keine Features verarbeiten
# - [ ] Modell benötigt sehr lange zum Training

# %% [markdown]
# **9. Welche Bibliothek ist im AMALEA-Kurs für das Tracking von Experimenten und Modellversionen vorgesehen?** (2 Punkte)
# - [ ] TensorBoard
# - [ ] MLflow
# - [ ] Matplotlib
# - [ ] Flask

# %% [markdown]
# **10. Was ist ein Vorteil von Random Forests gegenüber einzelnen Entscheidungsbäumen?** (2 Punkte)
# - [ ] Sie sind immer schneller
# - [ ] Sie reduzieren Overfitting durch Aggregation vieler Bäume
# - [ ] Sie benötigen weniger Daten
# - [ ] Sie können keine Klassifikation durchführen

# %% [markdown]
# **11. Welche Aussage zu K-Nearest Neighbors (KNN) ist korrekt?** (2 Punkte)
# - [ ] KNN benötigt ein trainiertes Modell mit Gewichten
# - [ ] KNN ist ein instanzbasiertes Verfahren und speichert alle Trainingsdaten
# - [ ] KNN kann keine numerischen Features verarbeiten
# - [ ] KNN ist robust gegenüber Ausreißern

# %% [markdown]
# **12. Was ist ein typischer Anwendungsfall für Principal Component Analysis (PCA)?** (2 Punkte)
# - [ ] Modell-Deployment
# - [ ] Dimensionsreduktion und Visualisierung
# - [ ] Hyperparameter-Tuning
# - [ ] Datenaugmentation

# %% [markdown]
# **13. Welche Rolle spielt die Standardisierung von Features bei der Anwendung von KNN?** (2 Punkte)
# - [ ] Sie ist irrelevant, da KNN keine Distanzen nutzt
# - [ ] Sie ist wichtig, da KNN auf Distanzmaßen basiert
# - [ ] Sie ist nur bei Textdaten notwendig
# - [ ] Sie ist nur für Zielvariablen relevant

# %% [markdown]
# **14. Welche Aussage zu Cross-Validation ist korrekt?** (2 Punkte)
# - [ ] Cross-Validation dient der Hyperparameter-Optimierung, nicht der Modellbewertung
# - [ ] Cross-Validation reduziert die Varianz der Modellbewertung
# - [ ] Cross-Validation ist nur bei Deep Learning relevant
# - [ ] Cross-Validation ist identisch mit Holdout-Validierung

# %% [markdown]
# **15. Was ist ein typischer Nachteil von linearen Modellen bei komplexen Datensätzen?** (2 Punkte)
# - [ ] Sie sind zu langsam
# - [ ] Sie können nicht mit kategorialen Variablen umgehen
# - [ ] Sie können nicht-lineare Zusammenhänge nicht abbilden
# - [ ] Sie benötigen GPU-Beschleunigung

# %% [markdown]
# **16. Welche Aussage zu Data Augmentation im Kontext von Computer Vision ist korrekt?** (2 Punkte)
# - [ ] Data Augmentation ist nur für Textdaten sinnvoll
# - [ ] Data Augmentation kann helfen, Overfitting zu reduzieren
# - [ ] Data Augmentation verschlechtert die Modellgüte
# - [ ] Data Augmentation ist nur im Deployment relevant

# %% [markdown]
# **17. Was ist ein typischer Vorteil von Transfer Learning im Vergleich zu Training from Scratch?** (2 Punkte)
# - [ ] Geringerer Datenbedarf und schnellere Konvergenz
# - [ ] Schlechtere Generalisierung
# - [ ] Nur für tabellarische Daten geeignet
# - [ ] Keine Vorteile, da Modelle immer neu trainiert werden müssen

# %% [markdown]
# **18. Welche Aussage zu Hyperparametern ist korrekt?** (2 Punkte)
# - [ ] Hyperparameter werden während des Trainings automatisch gelernt
# - [ ] Hyperparameter müssen vor dem Training festgelegt und ggf. optimiert werden
# - [ ] Hyperparameter sind nur bei linearen Modellen relevant
# - [ ] Hyperparameter sind identisch mit Modellgewichten

# %% [markdown]
# **19. Was ist ein typischer Fehler bei der Modellbewertung?** (2 Punkte)
# - [ ] Nutzung von Cross-Validation
# - [ ] Nutzung der Testdaten für Hyperparameter-Tuning
# - [ ] Nutzung von Trainingsdaten für das Training
# - [ ] Nutzung von Validierungsdaten für die Modellbewertung

# %% [markdown]
# **20. Welche Aussage zu Explainable AI (XAI) ist korrekt?** (2 Punkte)
# - [ ] XAI ist nur für Deep Learning relevant
# - [ ] XAI hilft, Modelle und deren Entscheidungen nachvollziehbar zu machen
# - [ ] XAI verschlechtert die Modellgüte
# - [ ] XAI ist nur für Bilddaten relevant

# %% [markdown]
# ## Offene Fragen

# %% [markdown]
# 1. Beschreiben Sie detailliert die sechs Phasen des QUA³CK-Prozessmodells und geben Sie für jede Phase ein konkretes Beispiel aus einem Data-Science-Projekt. (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 2. Erklären Sie, wie Sie in Python mit Pandas und Scikit-learn einen vollständigen Machine-Learning-Workflow (inkl. Datenimport, EDA, Feature Engineering, Modelltraining, Evaluation) umsetzen würden. (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 3. Diskutieren Sie die Bedeutung und die Herausforderungen von Data Leakage im Machine Learning. Wie kann man es erkennen und vermeiden? (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 4. Skizzieren Sie die Schritte zur Entwicklung einer Streamlit-App für ein ML-Modell, das auf tabellarischen Daten basiert. Welche Herausforderungen können dabei auftreten? (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 5. Vergleichen Sie die Vor- und Nachteile von Random Forests und K-Nearest Neighbors für Klassifikationsaufgaben. (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 6. Erklären Sie, wie Sie mit MLflow ein Experiment-Tracking für verschiedene Modellvarianten aufsetzen würden. Welche Vorteile bietet dies im MLOps-Kontext? (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 7. Beschreiben Sie, wie Sie mit Transfer Learning ein Computer-Vision-Projekt im AMALEA-Kontext umsetzen würden. Welche Schritte sind notwendig? (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 8. Diskutieren Sie die Rolle von Cross-Validation und Hyperparameter-Tuning für die Modellgüte. Wie gehen Sie dabei praktisch vor? (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 9. Analysieren Sie, wie Sie mit Exploratory Data Analysis (EDA) typische Fehlerquellen und Ausreißer in einem Datensatz identifizieren und adressieren würden. (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
# 10. Reflektieren Sie, wie Explainable AI (XAI) die Akzeptanz von ML-Modellen in Unternehmen beeinflussen kann. Geben Sie Beispiele für Methoden und deren Nutzen. (5 Punkte)
# <br><br><br><br><br><br><br><br><br><br>
